# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Resources/healthcare-dataset-stroke-data.csv')
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
med_df = df[['gender','age','hypertension','heart_disease','avg_glucose_level','bmi','smoking_status','stroke']]
med_df
# Out:
#       gender   age  hypertension  heart_disease  avg_glucose_level   bmi  \
# 0       Male  67.0             0              1             228.69  36.6
# 1     Female  61.0             0              0             202.21   NaN
# 2       Male  80.0             0              1             105.92  32.5
# 3     Female  49.0             0              0             171.23  34.4
# 4     Female  79.0             1              0             174.12  24.0
# ...      ...   ...           ...            ...                ...   ...
# 5105  Female  80.0             1              0              83.75   NaN
# 5106  Female  81.0             0              0             125.20  40.0
# 5107  Female  35.0             0              0              82.99  30.6
# 5108    Male  51.0             0              0             166.29  25.6
# 5109  Female  44.0             0              0              85.28  26.2
#
#        smoking_status  stroke
# 0     formerly smoked       1
# ...

# %%
med_df.isnull().sum()
# Out:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %%
med_df = med_df.dropna()

# %%
X = med_df.drop(columns
